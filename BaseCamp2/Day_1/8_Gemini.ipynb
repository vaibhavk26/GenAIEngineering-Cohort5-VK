# %% [markdown]
# ### Gemini Usage for LLM ###
# **Library Need**
# To use the APIs provided by the Geimi platform, the library 'Google GenAI' is required.
# Ensure to have performed 'pip install google-genai dotenv'
# The API key from your Google AI account would be required to execute this code

# %%
# Import required class from Google
from google import genai
from google.genai import types
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
client = genai.Client()

# Client = genai.Client (api_key='Your API Key')

# %% [markdown]
# **Invoke for chat Completion**
# >We try Gemini to get response from LLM
# >Note the differece in terms of API

# %%
response = client.models.generate_content(
                model="gemini-2.5-flash", 
                contents="I am not a hardware specialist. Explain GPU vs TPU to me."
            )
print(response.text)
# Out:
# Okay, let's break down GPU vs. TPU without getting bogged down in hardware jargon. Think of it like this:
#
# ## The Analogy: A Chef vs. A Specialized Pizza Machine
#
# Imagine you need to prepare food.
#
# *   **GPU = The Super Talented Chef**
#     *   This chef is incredibly skilled and versatile. They can cook almost anything: bake a cake, grill a steak, make a fancy salad, or even prepare a batch of cookies.
#     *   They are especially good at preparing **many portions of the *same* or *similar* dishes at once**. If you need 100 steaks, they can fire up multiple grills and coordinate their assistants to get it done efficiently.
#     *   This versatility makes them great for a wide range of tasks.
#
# *   **TPU = The Highly Specialized, Automated Pizza-Making Machine**
#     *   This machine was **built from the ground up to do one thing exceptionally well: make pizza.** It has custom conveyor belts, robotic arms for adding toppings, and ovens perfectly calibrated for pizza.
#     *   It can churn out thousands of perfect pizzas an hour, faster and more efficiently than even the most talented chef could ever hope to do **if all you need is pizza**.
#     *   However, ask it to bake a cake or grill a steak, and it's completely useless. It only makes pizza.
#
# ---
#
# ## Now, let's apply that to computers:
#
# ### GPU (Graphics Processing Unit)
#
# *   **Origin Story:** GPUs were originally designed to render graphics for video games and professional design. Think about all the calculations needed to display a complex 3D world in real-time – millions of tiny dots (pixels) changing color and position constantly.
# *   **How it Works (Simply):** GPUs have thousands of small, relatively simple "cores" (like our chef's assistants) that can all work on small parts of a problem **simultaneously**. This is called "parallel processing."
# *   **Why it's Useful Beyond Graphics:** It turns out that many tasks, like **Machine Learning/AI, scientific simulations, or even cryptocurrency mining,** involve doing *many small, similar calculations over and over again*. This is exactly what a GPU is good at.
# *   **The Chef Analogy:** It's the versatile, powerful chef. It can do many different types of parallel computations very well.
#
# ### TPU (Tensor Processing Unit)
#
# *   **Origin Story:** Google created TPUs specifically because they had a massive problem: their AI models (like the ones powering Google Search, Translate, Assistant, etc.) were becoming incredibly complex and required enormous amounts of computing power to train and run. While GPUs were good, Google needed something *even better and more efficient* for their specific AI tasks.
# *   **How it Works (Simply):** TPUs are custom-designed chips **optimized specifically for the mathematical operations that are most common in Machine Learning (especially neural networks)**. Think of things like matrix multiplications (which are fundamental to how AI learns). It's like the AI algorithms are almost "baked into" the hardware itself.
# *   **Why it's so Good for AI:** Because it's so specialized, a TPU can perform these specific AI calculations with incredible speed and power efficiency, often outperforming a general-purpose GPU for these tasks.
# *   **The Pizza Machine Analogy:** It's the ultra-specialized pizza machine. It does AI calculations (specifically, "tensor" operations – a type of data structure used in AI) incredibly fast and efficiently, but it's not designed for other types of computing.
# *   **Who Uses Them:** Primarily Google (they designed it, they use it in their own data centers and offer it through their Google Cloud Platform).
#
# ---
#
# ## Key Differences & When You'd Use Which:
#
# | Feature           | GPU (Graphics Processing Unit)                       | TPU (Tensor Processing Unit)                                 |
# | :---------------- | :--------------------------------------------------- | :----------------------------------------------------------- |
# | **Primary Design** | General-purpose parallel computing (originally graphics) | Highly specialized for **Machine Learning/AI (TensorFlow/JAX)** |
# | **Flexibility**   | **High** - can do many different kinds of tasks      | **Low** - optimized for a very specific type of computation  |
# | **Performance**   | Excellent for many parallel tasks, *very good* for AI | **Unbeatable for specific AI tasks** (training and inference) |
# | **Availability**  | Widely available (NVIDIA, AMD), consumer & professional | Mostly available through Google Cloud Platform               |
# | **Analogy**       | The versatile, super talented **Chef**               | The ultra-specialized **Pizza-Making Machine**               |
#
# **In short:**
#
# *   If you need a powerful, versatile workhorse for a variety of tasks that involve parallel processing (gaming, video editing, scientific simulations, general-purpose AI, cryptocurrency), you use a **GPU**.
# *   If you are Google, or you are running massive, repetitive AI workloads specifically designed for its architecture (especially with frameworks like TensorFlow or JAX), you would use a **TPU** for maximum speed and efficiency in that specific domain.
#
# Neither is inherently "better" than the other; they are designed for different sweet spots!

# %%
# There is a specific instruction given 
Instruction = "Continue the statement and make it 50 words"
Statement  = "When we get to see new AI models every week ..."
# Statement  = "Though we get to see new AI models every week ..."
# Statement  = "RAG is useful in scenarios ..."

# Invoke multiple times ...
# ?? What do we expect 
for i in range (3):
    
    response = client.models.generate_content(
                    model="gemini-2.5-flash-lite",
                    # model="gemini-flash-lite-latest",
                    config =types.GenerateContentConfig(
                                system_instruction=Instruction,),
                    contents =Statement
    )

    print(response.text)
# Out:
# When we get to see new AI models every week, it's both exhilarating and a little overwhelming. The pace of innovation is breathtaking, promising advancements in everything from healthcare to creative arts. However, it also raises critical questions about responsible development, ethical deployment, and the potential societal impact of such rapidly evolving technology.
# When we get to see new AI models every week, it's a dizzying testament to rapid progress, promising revolutionary advancements across countless fields. However, this breakneck pace also raises crucial questions about ethics, job displacement, and the potential for misuse, demanding careful consideration and proactive regulation to ensure responsible development and deployment.
# When we get to see new AI models every week, it's a thrilling testament to the rapid pace of innovation. Each release pushes the boundaries of what's possible, offering enhanced capabilities in areas like natural language processing, image generation, and complex problem-solving. This constant evolution promises to revolutionize industries and our daily lives.
